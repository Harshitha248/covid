# %% [raw]
# United States Covid_19
# This is the data repository for the 2019 Novel Corona Visual Dashboard operated by Johns Hopkins University Center for System Science and Engineering. also supported by ESRI Living Areas Team and the John Hopkins University applied physics lab.
#
# Corona Virus is a family o viruses that can cause illness, which can vary from common cold and cough to sometimes more severe disease.Middle East respiratory Syndrome(MERS-cov) and Severe accurate Respiratory Syndrome (SARS-Cov) were such severe cases with the worl already has faced. SARS-Cov-2 (n_coronavirus) is the new virus of the corona virus family which first discovered in 2019, which has not identified in humans befor. It is contigous virus which started from Wuhan in December 2019.
# which later declared as pandemic by WHO due to high rate spreads throughout the world. on May 20, 2020, this leads to a total of 300k+ Deaths across the globe, including the 90k+ deaths alone in U.S.A. The dataset is provided to identify the deaths and recovered cases

# %% [raw]
# Feature description
# Province_state :- The name of the state within the USA
# Country_Region :-The name of the Country (US).
# Last_Update :- The most recent date the file was pushed.
# Long_ :- Longitude.
# Confirmed - Aggregated confirmed case count for the state.
# Deaths - Aggregated Death case count for the state
# Recovered - Aggregated Recovered case count for the state.
# Active - Aggregated confirmed cases that have not been resolved (Active = Confirmed - Recovered - Deaths).
# FIPS - Federal Information Processing Standards code that uniquely identifies counties within the USA.
# Incident_Rate - confirmed cases per 100,000 persons.
# People_Tested - Total number of people who have been tested.
# People_Hospitalized - Total number of people hospitalized.
# Mortality_Rate - Number recorded deaths * 100/ Number confirmed cases.
# UID - Unique Identifier for each row entry.
# ISO3 - Officialy assigned country code identifiers.
# Testing_Rate - Total number of people tested per 100,000 persons.
# Hospitalization_Rate - Total number of people hospitalized * 100/ Number of confirmed cases.
#
# Field description
#
# FIPS:- US only. Federal Information Processing stadards code that uniquely identifies countries within the USA
# Admin2: Country name. US only
# Province_State:- Province, State or dependency name
# Country_region:Country, region, or Sovereignty name. The name of locations included on the Website correspond with the official designation used by the U.S. Department of State.
# lat Update:-MM/DD/YYYY HH:mm:ss(24 hour format, in UTC)
# Lat and Long_: Dot locations on the dashboard. All points (except for Australia) shown on the map are based on geographic centroids, and are not representative of a specific address, building or any location at a spatial scale finer than a province/state. Australian dots are located at the centroid of the largest city in each state.
# Confirmed: Confirmed cases include presumptive positive cases and probable cases, in accordance with CDC guidelines as of April 14.
# Deaths: Death totals in the US include confirmed and probable, in accordance with CDC guidelines as of April 14.
# Recovered: Recovered cases outside China are estimates based on local media reports, and state and local reporting when available, and therefore may be substantially lower than the true number. US state-level recovered cases are from COVID Tracking Project.
# Active: Active cases = total confirmed - total recovered - total deaths.
# Incidence_Rate: Admin2 + Province_State + Country_Region.
# Case-Fatality Ratio (%): = confirmed cases per 100,000 persons.
# US Testing Rate: = total test results per 100,000 persons. The "total test results" is equal to "Total test results (Positive + Negative)" from COVID Tracking Project.
# US Hospitalization Rate (%): = Total number hospitalized / Number confirmed cases. The "Total number hospitalized" is the "Hospitalized – Cumulative" count from COVID Tracking Project. The "hospitalization rate" and "hospitalized - Cumulative" data is only presented for those states which provide cumulative hospital data.

# %%
#importing the required libraries
import numpy as np#for data Analysis
import pandas as pd#for Scientific computation
import matplotlib.pyplot as plt#for data Visualization
import seaborn as sns#for data visualization
sns.set()

# %%
# Reading the data
df=pd.read_csv(r"covid.csv")

# %%
# reading the fist five coulmns
df.head()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 0         Alabama             US  2020-05-21 02:32:54  32.3182  -86.9023
# 1          Alaska             US  2020-05-21 02:32:54  61.3707 -152.4044
# 2  American Samoa             US  2020-05-21 02:32:54 -14.2710 -170.1320
# 3         Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 4        Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      13052     522        NaN  12530.0     1     266.194321       164450.0
# 1        401      10      352.0     39.0     2      54.815493        37045.0
# 2          0       0        NaN      0.0    60       0.000000          124.0
# 3      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 4       5003     107     3852.0   1044.0     5     165.782801        96258.0
#
# ...

# %%
#reading the last five columns
df.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 53       Virginia             US  2020-05-21 02:32:54  37.7693  -78.1700
# 54     Washington             US  2020-05-21 02:32:54  47.4009 -121.4905
# 55  West Virginia             US  2020-05-21 02:32:54  38.4912  -80.9545
# 56      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 57        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 53      32908    1075     4523.0  27310.0    51     385.541875       212626.0
# 54      18971    1037        NaN  17934.0    53     249.130224       293120.0
# 55       1567      69      950.0    548.0    54      87.437024        80641.0
# 56      13413     481     7728.0   5204.0    55     230.367575       167713.0
# 57        787      11      528.0    248.0    56     135.980607        18840.0
#
# ...

# %%
# checking the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Province_State        58 non-null     object
#  1   Country_Region        58 non-null     object
#  2   Last_Update           58 non-null     object
#  3   Lat                   56 non-null     float64
#  4   Long_                 56 non-null     float64
#  5   Confirmed             58 non-null     int64
#  6   Deaths                58 non-null     int64
#  7   Recovered             42 non-null     float64
#  8   Active                58 non-null     float64
#  9   FIPS                  58 non-null     int64
#  10  Incident_Rate         56 non-null     float64
#  11  People_Tested         56 non-null     float64
#  12  People_Hospitalized   33 non-null     float64
#  13  Mortality_Rate        57 non-null     float64
#  14  UID                   58 non-null     int64
# ...

# %%
#checking the dtypes
df.dtypes
# Out:
# Province_State           object
# Country_Region           object
# Last_Update              object
# Lat                     float64
# Long_                   float64
# Confirmed                 int64
# Deaths                    int64
# Recovered               float64
# Active                  float64
# FIPS                      int64
# Incident_Rate           float64
# People_Tested           float64
# People_Hospitalized     float64
# Mortality_Rate          float64
# UID                       int64
# ISO3                     object
# Testing_Rate            float64
# Hospitalization_Rate    float64
# dtype: object

# %%
#describing the dataset
df.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  56.000000   56.000000      58.000000     58.000000     42.000000
# mean   36.840089  -85.206614   26756.086207   1611.017241   7007.428571
# std    10.887035   49.754449   52562.031122   4084.750891  11674.490020
# min   -14.271000 -170.132000       0.000000      0.000000     13.000000
# 25%    34.594600 -101.165775    2596.000000     74.000000    970.000000
# 50%    39.061850  -87.944200   10148.500000    385.000000   3008.000000
# 75%    42.361650  -76.970625   29395.500000   1394.250000   7326.750000
# max    61.370700  145.673900  354370.000000  28636.000000  61886.000000
#
#               Active          FIPS  Incident_Rate  People_Tested  \
# count      58.000000     58.000000      56.000000   5.600000e+01
# mean    20070.724138   3288.086207     396.230806   2.258534e+05
# std     41294.705318  17408.350591     402.682539   2.987834e+05
# ...

# %%
#checking the columns of the dataset
df.columns
# Out:
# Index(['Province_State', 'Country_Region', 'Last_Update', 'Lat', 'Long_',
#        'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate',
#        'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'ISO3',
#        'Testing_Rate', 'Hospitalization_Rate'],
#       dtype='object')

# %%
#Checking the missing value present in the dataset
missing_values=[x for x in df.columns if df[x].isnull().sum()>1]
print('Number of missing variable columns:', len(missing_values))
print("Missing values in the dataset : \n ", missing_values)
print("-"*125)
df[missing_values].head()
# Out:
# Number of missing variable columns: 8
# Missing values in the dataset :
#   ['Lat', 'Long_', 'Recovered', 'Incident_Rate', 'People_Tested', 'People_Hospitalized', 'Testing_Rate', 'Hospitalization_Rate']
# -----------------------------------------------------------------------------------------------------------------------------
#        Lat     Long_  Recovered  Incident_Rate  People_Tested  \
# 0  32.3182  -86.9023        NaN     266.194321       164450.0
# 1  61.3707 -152.4044      352.0      54.815493        37045.0
# 2 -14.2710 -170.1320        NaN       0.000000          124.0
# 3  33.7298 -111.4312     3773.0     204.788838       165435.0
# 4  34.9697  -92.3731     3852.0     165.782801        96258.0
#
#    People_Hospitalized  Testing_Rate  Hospitalization_Rate
# 0               1493.0   3353.942386             11.438860
# 1                  NaN   5063.940017                   NaN
# 2                  NaN    222.857246                   NaN
# ...

# %% [raw]
# Checking the percentage of missing values

# %%
#checking the percentage of the missing values
for feature in missing_values:
    print(feature, np.round(df[feature].isnull().mean()*100,4), "% Missing Values")
# Out:
# Lat 3.4483 % Missing Values
# Long_ 3.4483 % Missing Values
# Recovered 27.5862 % Missing Values
# Incident_Rate 3.4483 % Missing Values
# People_Tested 3.4483 % Missing Values
# People_Hospitalized 43.1034 % Missing Values
# Testing_Rate 3.4483 % Missing Values
# Hospitalization_Rate 43.1034 % Missing Values

# %% [raw]
# observation:-
# 1. There are many missing values in the columns of the dataset
# 2. Hence need to check the relationship with confirmed

# %%
# replacing the missing value with 1 and not missed value with 0 
for feature in missing_values:
    data=df.copy()
    data[feature]=np.where(data[feature].isnull(),1,0)
    data.groupby(feature)["Confirmed"].median().plot.bar()
    plt.title(feature)
    plt.show()

# %% [raw]
# 1. The relation between the missing value and the dependent variable is clearly visible.
# 2. so we need to replace these nan values

# %% [raw]
# extracting all numerical feature

# %%
#checking how many numerical values present in the dataset
numerical_features=[x for x in df.columns if df[x].dtypes != "O"]
print("The number of the numerical columns in the dataset:", len(numerical_features))
print("Numerical columns in the dataset:\n", numerical_features)
print("-"*125)
df[numerical_features].head()
# Out:
# The number of the numerical columns in the dataset: 14
# Numerical columns in the dataset:
#  ['Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate', 'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'Testing_Rate', 'Hospitalization_Rate']
# -----------------------------------------------------------------------------------------------------------------------------
#        Lat     Long_  Confirmed  Deaths  Recovered   Active  FIPS  \
# 0  32.3182  -86.9023      13052     522        NaN  12530.0     1
# 1  61.3707 -152.4044        401      10      352.0     39.0     2
# 2 -14.2710 -170.1320          0       0        NaN      0.0    60
# 3  33.7298 -111.4312      14906     747     3773.0  10386.0     4
# 4  34.9697  -92.3731       5003     107     3852.0   1044.0     5
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 0     266.194321       164450.0               1493.0        3.999387
# ...

# %%
#Extracting the dicrete and continous variable
discrete_feature=[x for x in numerical_features if len(df[x].unique())<25 ]
print("The number of discrete column in the dataset:", len(discrete_feature))
print("Discrete columns in the datset: \n", discrete_feature)
print("-"*125)
df[discrete_feature].head()
# Out:
# The number of discrete column in the dataset: 0
# Discrete columns in the datset:
#  []
# -----------------------------------------------------------------------------------------------------------------------------
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]

# %%
# extracting the continous variable
continous_feature=[x for x in numerical_features if x not in discrete_feature]
print("The number of continous feature column in the dataset :",len(continous_feature))
print("Continous feature columns in the dataset :\n",continous_feature)
print("-"*125)
df[continous_feature].head()
# Out:
# The number of continous feature column in the dataset : 14
# Continous feature columns in the dataset :
#  ['Lat', 'Long_', 'Confirmed', 'Deaths', 'Recovered', 'Active', 'FIPS', 'Incident_Rate', 'People_Tested', 'People_Hospitalized', 'Mortality_Rate', 'UID', 'Testing_Rate', 'Hospitalization_Rate']
# -----------------------------------------------------------------------------------------------------------------------------
#        Lat     Long_  Confirmed  Deaths  Recovered   Active  FIPS  \
# 0  32.3182  -86.9023      13052     522        NaN  12530.0     1
# 1  61.3707 -152.4044        401      10      352.0     39.0     2
# 2 -14.2710 -170.1320          0       0        NaN      0.0    60
# 3  33.7298 -111.4312      14906     747     3773.0  10386.0     4
# 4  34.9697  -92.3731       5003     107     3852.0   1044.0     5
#
#    Incident_Rate  People_Tested  People_Hospitalized  Mortality_Rate  \
# 0     266.194321       164450.0               1493.0        3.999387
# ...

# %%
# Representation of continous numerical features

for feature in continous_feature:
    data=df.copy()
    data[feature].hist(bins=25)
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [raw]
# 1. Most of the features are right skewed
# 2.Need to go to log transform

# %%
for feature in continous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data[ 'Confirmed']=np.log(data[ 'Confirmed'])
        plt.scatter(data[feature],data[ 'Confirmed'])
        plt.xlabel(feature)
        plt.ylabel( 'Confirmed')
        plt.title(feature)
        plt.show()
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arraylike.py:274: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arraylike.py:274: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
for feature in continous_feature:
    data=df.copy()
    if 0 in data[feature].unique():
        pass
    else:
        data[feature]=np.log(data[feature])
        data.boxplot(feature)
        plt.ylabel(feature)
        plt.title(feature)
        plt.show()
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\pandas\core\arraylike.py:274: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %% [raw]
# # there are lot of the outliers and outlier treatment is required

# %%
#categorical_features
categorical_features=[x for x in df.columns if df[x].dtypes=='O']
print("The number of categorical column in the dataset :",len(categorical_features))
print("Categorical feature columns in the dataset :\n",categorical_features)
print("-"*125)
df[categorical_features].head()
# Out:
# The number of categorical column in the dataset : 4
# Categorical feature columns in the dataset :
#  ['Province_State', 'Country_Region', 'Last_Update', 'ISO3']
# -----------------------------------------------------------------------------------------------------------------------------
#    Province_State Country_Region          Last_Update ISO3
# 0         Alabama             US  2020-05-21 02:32:54  USA
# 1          Alaska             US  2020-05-21 02:32:54  USA
# 2  American Samoa             US  2020-05-21 02:32:54  ASM
# 3         Arizona             US  2020-05-21 02:32:54  USA
# 4        Arkansas             US  2020-05-21 02:32:54  USA

# %%
#checking the unique items in categorical variables
for feature in categorical_features:
    print("The unique values in the column",feature,":",df[feature].nunique())
# Out:
# The unique values in the column Province_State : 58
# The unique values in the column Country_Region : 1
# The unique values in the column Last_Update : 1
# The unique values in the column ISO3 : 6

# %%
#Relationship between categorical column and Confirmed
for feature in categorical_features:
    data=df.copy()
    data.groupby(feature)['Confirmed'].median().plot.bar()
    plt.xlabel(feature)
    plt.ylabel('Confirmed')
    plt.title(feature)
    plt.show()

# %%
df.isnull().sum()
# Out:
# Province_State           0
# Country_Region           0
# Last_Update              0
# Lat                      2
# Long_                    2
# Confirmed                0
# Deaths                   0
# Recovered               16
# Active                   0
# FIPS                     0
# Incident_Rate            2
# People_Tested            2
# People_Hospitalized     25
# Mortality_Rate           1
# UID                      0
# ISO3                     0
# Testing_Rate             2
# Hospitalization_Rate    25
# dtype: int64

# %%
data_no_miss_val = df.dropna()

# %%
data_no_miss_val.isnull().sum()
# Out:
# Province_State          0
# Country_Region          0
# Last_Update             0
# Lat                     0
# Long_                   0
# Confirmed               0
# Deaths                  0
# Recovered               0
# Active                  0
# FIPS                    0
# Incident_Rate           0
# People_Tested           0
# People_Hospitalized     0
# Mortality_Rate          0
# UID                     0
# ISO3                    0
# Testing_Rate            0
# Hospitalization_Rate    0
# dtype: int64

# %%
data_no_miss_val.describe(include="all")
# Out:
#        Province_State Country_Region          Last_Update        Lat  \
# count              27             27                   27  27.000000
# unique             27              1                    1        NaN
# top            Kansas             US  2020-05-21 02:32:54        NaN
# freq                1             27                   27        NaN
# mean              NaN            NaN                  NaN  39.579870
# std               NaN            NaN                  NaN   5.719976
# min               NaN            NaN                  NaN  21.094300
# 25%               NaN            NaN                  NaN  35.656550
# 50%               NaN            NaN                  NaN  40.150000
# 75%               NaN            NaN                  NaN  44.254500
# max               NaN            NaN                  NaN  47.528900
#
#              Long_      Confirmed        Deaths     Recovered         Active  \
# ...

# %%
data_conf_pos = data_no_miss_val[data_no_miss_val["Confirmed"] >=0]
data_conf_pos.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  27.000000   27.000000      27.000000     27.000000     27.000000
# mean   39.579870  -95.279459   24137.925926   1573.185185   5846.629630
# std     5.719976   19.562585   66961.033471   5462.200733  11641.005515
# min    21.094300 -157.498300     478.000000     11.000000    440.000000
# 25%    35.656550 -106.775500    3834.500000     83.500000   1288.500000
# 50%    40.150000  -93.900200    8167.000000    299.000000   3023.000000
# 75%    44.254500  -79.557500   16288.000000    658.500000   4987.000000
# max    47.528900  -69.381900  354370.000000  28636.000000  61886.000000
#
#               Active       FIPS  Incident_Rate  People_Tested  \
# count      27.000000  27.000000      27.000000   2.700000e+01
# mean    16718.111111  31.333333     377.854090   1.736362e+05
# std     50332.706229  15.568706     405.143373   2.766633e+05
# min        22.000000   4.000000      44.723974   1.884000e+04
# ...

# %%
data_death_pos = data_conf_pos[data_conf_pos["Deaths"] >=0]
data_death_pos.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  27.000000   27.000000      27.000000     27.000000     27.000000
# mean   39.579870  -95.279459   24137.925926   1573.185185   5846.629630
# std     5.719976   19.562585   66961.033471   5462.200733  11641.005515
# min    21.094300 -157.498300     478.000000     11.000000    440.000000
# 25%    35.656550 -106.775500    3834.500000     83.500000   1288.500000
# 50%    40.150000  -93.900200    8167.000000    299.000000   3023.000000
# 75%    44.254500  -79.557500   16288.000000    658.500000   4987.000000
# max    47.528900  -69.381900  354370.000000  28636.000000  61886.000000
#
#               Active       FIPS  Incident_Rate  People_Tested  \
# count      27.000000  27.000000      27.000000   2.700000e+01
# mean    16718.111111  31.333333     377.854090   1.736362e+05
# std     50332.706229  15.568706     405.143373   2.766633e+05
# min        22.000000   4.000000      44.723974   1.884000e+04
# ...

# %%
data_recove_pos = data_death_pos[data_death_pos["Recovered"] >=0]
data_recove_pos.describe()
# Out:
#              Lat       Long_      Confirmed        Deaths     Recovered  \
# count  27.000000   27.000000      27.000000     27.000000     27.000000
# mean   39.579870  -95.279459   24137.925926   1573.185185   5846.629630
# std     5.719976   19.562585   66961.033471   5462.200733  11641.005515
# min    21.094300 -157.498300     478.000000     11.000000    440.000000
# 25%    35.656550 -106.775500    3834.500000     83.500000   1288.500000
# 50%    40.150000  -93.900200    8167.000000    299.000000   3023.000000
# 75%    44.254500  -79.557500   16288.000000    658.500000   4987.000000
# max    47.528900  -69.381900  354370.000000  28636.000000  61886.000000
#
#               Active       FIPS  Incident_Rate  People_Tested  \
# count      27.000000  27.000000      27.000000   2.700000e+01
# mean    16718.111111  31.333333     377.854090   1.736362e+05
# std     50332.706229  15.568706     405.143373   2.766633e+05
# min        22.000000   4.000000      44.723974   1.884000e+04
# ...

# %%
data_pos = data_recove_pos

# %%
data_pos.describe(include="all")
# Out:
#        Province_State Country_Region          Last_Update        Lat  \
# count              27             27                   27  27.000000
# unique             27              1                    1        NaN
# top            Kansas             US  2020-05-21 02:32:54        NaN
# freq                1             27                   27        NaN
# mean              NaN            NaN                  NaN  39.579870
# std               NaN            NaN                  NaN   5.719976
# min               NaN            NaN                  NaN  21.094300
# 25%               NaN            NaN                  NaN  35.656550
# 50%               NaN            NaN                  NaN  40.150000
# 75%               NaN            NaN                  NaN  44.254500
# max               NaN            NaN                  NaN  47.528900
#
#              Long_      Confirmed        Deaths     Recovered         Active  \
# ...

# %%
sns.distplot(data_pos["Confirmed"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Confirmed', ylabel='Density'>

# %%
sns.distplot(data_pos["Deaths"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Deaths', ylabel='Density'>

# %%
sns.distplot(data_pos["Recovered"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Recovered', ylabel='Density'>

# %%
percentage_data=0.95

# %%
q = data_pos["Confirmed"].quantile(percentage_data)
q
# Out:
# 41331.2

# %%
data_confirmed_rm_out = data_pos[data_pos["Confirmed"] <q ]

# %%
sns.distplot(data_confirmed_rm_out["Confirmed"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Confirmed', ylabel='Density'>

# %%
q = data_confirmed_rm_out["Deaths"].quantile(percentage_data)
q
# Out:
# 1254.1999999999994

# %%
data_death_rm_out = data_confirmed_rm_out[data_confirmed_rm_out["Deaths"] <q]

# %%
sns.distplot(data_death_rm_out["Confirmed"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Confirmed', ylabel='Density'>

# %%
q=data_death_rm_out["Recovered"].quantile(percentage_data)
q
# Out:
# 11377.499999999993

# %%
data_recove_rm_out=data_death_rm_out[data_death_rm_out["Recovered"] < q]

# %%
sns.distplot(data_recove_rm_out["Recovered"])
# Out:
# c:\users\admin\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Recovered', ylabel='Density'>

# %%
data_clean = data_recove_rm_out.reset_index(drop=True)

# %%
data_clean.describe(include="all")
# Out:
#        Province_State Country_Region          Last_Update        Lat  \
# count              21             21                   21  21.000000
# unique             21              1                    1        NaN
# top            Kansas             US  2020-05-21 02:32:54        NaN
# freq                1             21                   21        NaN
# mean              NaN            NaN                  NaN  39.301286
# std               NaN            NaN                  NaN   6.267666
# min               NaN            NaN                  NaN  21.094300
# 25%               NaN            NaN                  NaN  34.969700
# 50%               NaN            NaN                  NaN  40.150000
# 75%               NaN            NaN                  NaN  44.268500
# max               NaN            NaN                  NaN  47.528900
#
#              Long_     Confirmed       Deaths    Recovered        Active  \
# ...

# %%
data_clean.head()
# Out:
#   Province_State Country_Region          Last_Update      Lat     Long_  \
# 0        Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 1       Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
# 2         Hawaii             US  2020-05-21 02:32:54  21.0943 -157.4983
# 3          Idaho             US  2020-05-21 02:32:54  44.2405 -114.4788
# 4         Kansas             US  2020-05-21 02:32:54  38.5266  -96.7265
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 1       5003     107     3852.0   1044.0     5     165.782801        96258.0
# 2        643      17      578.0     48.0    15      45.413710        46304.0
# 3       2506      77     1668.0    761.0    16     140.229930        38567.0
# 4       8507     202      473.0   7832.0    20     292.004226        71203.0
#
# ...

# %%
data_clean.tail()
# Out:
#    Province_State Country_Region          Last_Update      Lat     Long_  \
# 16   South Dakota             US  2020-05-21 02:32:54  44.2998  -99.4388
# 17           Utah             US  2020-05-21 02:32:54  40.1500 -111.8624
# 18       Virginia             US  2020-05-21 02:32:54  37.7693  -78.1700
# 19      Wisconsin             US  2020-05-21 02:32:54  44.2685  -89.6165
# 20        Wyoming             US  2020-05-21 02:32:54  42.7560 -107.3025
#
#     Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 16       4177      46     3023.0   1108.0    46     472.159329        30389.0
# 17       7710      90     4423.0   3197.0    49     240.489738       179664.0
# 18      32908    1075     4523.0  27310.0    51     385.541875       212626.0
# 19      13413     481     7728.0   5204.0    55     230.367575       167713.0
# 20        787      11      528.0    248.0    56     135.980607        18840.0
#
# ...

# %%
data_clean.describe()
# Out:
#              Lat       Long_     Confirmed       Deaths    Recovered  \
# count  21.000000   21.000000     21.000000    21.000000    21.000000
# mean   39.301286  -98.196962   7482.619048   276.095238  2820.380952
# std     6.267666   20.411919   7318.370765   280.061048  2244.192337
# min    21.094300 -157.498300    478.000000    11.000000   440.000000
# 25%    34.969700 -110.454400   2506.000000    73.000000  1100.000000
# 50%    40.150000  -96.928900   5532.000000   190.000000  1882.000000
# 75%    44.268500  -84.670100   9175.000000   407.000000  4266.000000
# max    47.528900  -69.381900  32908.000000  1075.000000  7728.000000
#
#              Active       FIPS  Incident_Rate  People_Tested  \
# count     21.000000  21.000000      21.000000      21.000000
# mean    4386.142857  33.095238     267.011156  101100.238095
# std     6203.673487  15.578526     254.145947   58526.426361
# min       22.000000   4.000000      44.723974   18840.000000
# ...

# %%
sns.pairplot(data_clean)

# %%
data_clean_us =data_clean[data_clean["Country_Region"] == "US"].reset_index(drop=True)
data_clean_us.head()
# Out:
#   Province_State Country_Region          Last_Update      Lat     Long_  \
# 0        Arizona             US  2020-05-21 02:32:54  33.7298 -111.4312
# 1       Arkansas             US  2020-05-21 02:32:54  34.9697  -92.3731
# 2         Hawaii             US  2020-05-21 02:32:54  21.0943 -157.4983
# 3          Idaho             US  2020-05-21 02:32:54  44.2405 -114.4788
# 4         Kansas             US  2020-05-21 02:32:54  38.5266  -96.7265
#
#    Confirmed  Deaths  Recovered   Active  FIPS  Incident_Rate  People_Tested  \
# 0      14906     747     3773.0  10386.0     4     204.788838       165435.0
# 1       5003     107     3852.0   1044.0     5     165.782801        96258.0
# 2        643      17      578.0     48.0    15      45.413710        46304.0
# 3       2506      77     1668.0    761.0    16     140.229930        38567.0
# 4       8507     202      473.0   7832.0    20     292.004226        71203.0
#
# ...

# %%
data_clean_us.describe()
# Out:
#              Lat       Long_     Confirmed       Deaths    Recovered  \
# count  21.000000   21.000000     21.000000    21.000000    21.000000
# mean   39.301286  -98.196962   7482.619048   276.095238  2820.380952
# std     6.267666   20.411919   7318.370765   280.061048  2244.192337
# min    21.094300 -157.498300    478.000000    11.000000   440.000000
# 25%    34.969700 -110.454400   2506.000000    73.000000  1100.000000
# 50%    40.150000  -96.928900   5532.000000   190.000000  1882.000000
# 75%    44.268500  -84.670100   9175.000000   407.000000  4266.000000
# max    47.528900  -69.381900  32908.000000  1075.000000  7728.000000
#
#              Active       FIPS  Incident_Rate  People_Tested  \
# count     21.000000  21.000000      21.000000      21.000000
# mean    4386.142857  33.095238     267.011156  101100.238095
# std     6203.673487  15.578526     254.145947   58526.426361
# min       22.000000   4.000000      44.723974   18840.000000
# ...
